# %% [markdown]
# #**configuracion de ambiente**
# ---

# %% [markdown]
# #**importacion de librerias y data save**

# %%
import pandas as pd
data = pd.read_csv ("/content/SoftwareProject_DataSet.csv")

# %% [markdown]
# #**Verificacion del dataSet**

# %%
data.head()
# Out:
#                      Proyecto    Módulo     Desarrollador  Líneas de código  \
# 0   Smith, Torres and Flowers      long     Patricia Ford              4227
# 1             Jordan and Sons      lose    Melissa Briggs              6124
# 2  Madden, Jackson and Keller  thousand  Alexander Spence               588
# 3                 Evans Group     table    Michael Porter              5796
# 4                 Pearson LLC     light    Andrew Gregory              3019
#
#    Número de bugs  Tiempo de desarrollo (horas)  Costo (USD)  \
# 0              39                           375        84053
# 1              37                           132        82167
# 2              30                           441        75204
# 3              17                            87        32147
# 4              11                           263        44998
#
#    Satisfacción del cliente  Antigüedad del desarrollador (años)  \
# 0                         1                                   10
# 1                         5                                    9
# 2                         3                                    7
# 3                         1                                    1
# 4                         2                                    5
#
#   Idioma de programación Plataforma   Tipo de proyecto Fase del proyecto  \
# 0                   Java     Mobile        Application        Deployment
# 1                 Kotlin     Mobile  Management System           Testing
# 2             Javascript     Mobile        Application        Deployment
# 3                 Kotlin     Mobile        Application            Design
# 4                 Python    Desktop           Web site       Development
#
#    Tamaño del equipo                Tecnologías
# 0                  7  professor, evidence, down
# 1                 10          clear, rich, tend
# 2                 10       process, cut, debate
# 3                  1    bank, management, those
# 4                  3         you, visit, camera

# %% [markdown]
# #**Obtener el tamaño de la poblacion**
#
#
# ---

# %%
population_size = len(data)
print("The population size is over",population_size)
# Out:
# The population size is over 10000

# %% [markdown]
# cREACION DE MUESTRA ALEATORIA SIMPLE DE 50 REGISTRO

# %%
sample_size = 50
simple_sample = data.sample(sample_size)

# %% [markdown]
# #**Revision de creacion de la muestra**

# %%
display(simple_sample)
# Out:
#                              Proyecto      Módulo       Desarrollador  \
# 8064    Steele, Thompson and Lawrence    property        Hector Nolan
# 7385                         Park Ltd     similar  Clayton Ramirez MD
# 3404                 Gonzalez-Johnson      speech       James Rowland
# 2711      Craig, Fisher and Rodriguez     history      Kelly Williams
# 2591           Colon, Adams and Davis     include        Derek Orozco
# 3751                        White LLC     because        Daniel Stone
# 3793       Jacobs, Watson and Johnson       whose     Karen Mccormick
# 9090    Greer, Villegas and Armstrong       issue     Gregory Nichols
# 4379       Kaufman, Aguilar and Bauer       level         Nicole Hill
# 1840         Ortiz, Wagner and Tanner       price            Adam Ray
# 2716                  Stewart-Jackson    shoulder       Teresa Patton
# 620                   Carroll-Bentley        mean         Seth Knight
# 552                           Lee PLC      common  Vanessa Mclaughlin
# 4050         Parker, Shaw and Lindsey       scene        Steven Moore
# 6634                    Cervantes Ltd      listen   Gabriel Rodriguez
# 7198                        Hines Inc         bag      Heather Strong
# 305                      Hanson Group      expert       Rachel Harvey
# 2441                       Norton LLC     discuss       Ruben Coleman
# 9271                       Turner PLC   newspaper         Brian Jones
# 2990                  Rodriguez Group      sister         Anna Harris
# 6546                     Barnes-Perez        fine     Matthew Johnson
# 9322          Ramirez, Scott and Ball         six       Megan Burgess
# 5458                   Haynes-Schultz        also         Justin Pena
# 4852                       Cobb Group      people   Christopher Evans
# 7757                  Barnett-Edwards   interview      Jennifer Marks
# 9310                 Martin-Stevenson    possible      Andrea Alvarez
# 8314          Cox, Carroll and Curtis         arm       Jessica Welch
# 7883                       Phelps Inc       coach          Seth Ayala
# 1098     Washington, Tran and Herring        with     Katherine Gates
# 3546                       Wong-Jones         old     Michael Skinner
# 5200                        Brown Inc        need       Sean Jennings
# 8440                    Morrison-Long      wonder         James Smith
# 8903                         Gray Ltd  management       Anthony Wells
# 1384                       Howard PLC        both      Cynthia Fisher
# 9767       Gordon, Smith and Williams       image     Lindsey Leblanc
# 7152                         Khan Ltd       sport           Tina Ball
# 4190           Cooke, Ross and Wagner        what      Edward Mcguire
# 3323            Wright, Boyd and Wood          no        Haley Harris
# 2772              Lin, Ware and Smith     thought      Rebecca Garcia
# 5060                    Stevens-Russo     prevent        James Watson
# 6135                         Long LLC       truth           Jose Pham
# 9620        West, Harris and Mckinney      policy           Joel Cook
# 5340                     Howard-Ellis       three        Scott Rogers
# 6913                  Kelley-Williams    strategy      Samantha Smith
# 236                      Rosales-Wood        fall         Terry Greer
# 2814                       Watson Ltd         boy       Ashley Taylor
# 7100                       Hunt Group     herself       Beth Marshall
# 4573  Robinson, Reynolds and Griffith         two         Adam Cooley
# 9242               Armstrong and Sons        take     Nicholas Gibson
# 8427                 Martinez-Pearson        look     Mr. Shawn Perez
#
#       Líneas de código  Número de bugs  Tiempo de desarrollo (horas)  \
# 8064              4203              16                           205
# 7385              8638              19                           500
# 3404              1857              37                            91
# 2711              4827              49                           142
# 2591               123              21                           490
# 3751              3733              20                           479
# 3793              9870               6                           374
# 9090              2890              23                           189
# 4379              1198              19                           424
# 1840              8738              42                           149
# 2716              8064              47                           413
# 620               6670              28                           177
# 552               2519              40                           427
# 4050              1634               6                           326
# 6634               919              38                            55
# 7198               508              21                            75
# 305               6715              42                           470
# 2441               376              35                           187
# 9271              7398              38                           214
# 2990              3248               0                           418
# 6546              3213              15                           335
# 9322              4830              34                           289
# 5458              4430               4                           284
# 4852              5343              49                           308
# 7757              8439               6                           350
# 9310              6738              31                           388
# 8314              8332              44                           375
# 7883              8740              16                           149
# 1098              7590              37                           449
# 3546               345              35                           187
# 5200              1496               9                           213
# 8440              8747               4                           176
# 8903              3186              19                           407
# 1384              2856              50                           436
# 9767              3487              45                           224
# 7152              5213              33                           202
# 4190              8945              47                            51
# 3323              8649              24                           347
# 2772              3687              49                           171
# 5060              3411              33                           123
# 6135              9587              44                           428
# 9620              7064              42                           237
# 5340              6523               7                           263
# 6913              5079               0                           364
# 236               6971              47                            50
# 2814              1812              26                           217
# 7100              7047               1                           399
# 4573               735              23                           402
# 9242              9644              28                           160
# 8427              1646              39                           446
#
#       Costo (USD)  Satisfacción del cliente  \
# 8064        19630                         1
# 7385        65141                         1
# 3404        84563                         5
# 2711        81093                         4
# 2591        95408                         5
# 3751        29911                         5
# 3793        90855                         3
# 9090        35866                         5
# 4379        17540                         1
# 1840         6703                         5
# 2716        70983                         5
# 620         96545                         1
# 552         33976                         3
# 4050        52978                         2
# 6634        21165                         5
# 7198        17472                         1
# 305         79729                         2
# 2441         3371                         5
# 9271        59829                         3
# 2990        96070                         4
# 6546        91824                         4
# 9322        40008                         5
# 5458        28229                         5
# 4852         1654                         3
# 7757        79094                         3
# 9310        30084                         4
# 8314        80900                         5
# 7883        61846                         3
# 1098        62007                         5
# 3546        49164                         4
# 5200        19951                         3
# 8440        81347                         3
# 8903        37269                         2
# 1384        65466                         5
# 9767        28624                         2
# 7152        54868                         4
# 4190        49665                         1
# 3323        70629                         5
# 2772        93188                         2
# 5060        78778                         5
# 6135        55340                         5
# 9620        25787                         5
# 5340        28805                         2
# 6913        64638                         4
# 236         59975                         4
# 2814         9836                         2
# 7100        12520                         1
# 4573        27565                         3
# 9242        95616                         4
# 8427        12961                         2
#
#       Antigüedad del desarrollador (años) Idioma de programación Plataforma  \
# 8064                                   12                 Kotlin    Desktop
# 7385                                   14                   Java    Desktop
# 3404                                    5             Javascript        Web
# 2711                                    6             Javascript        Web
# 2591                                    4             Javascript        Web
# 3751                                   12             Javascript     Mobile
# 3793                                    6                 Python    Desktop
# 9090                                    1             Javascript        Web
# 4379                                   14                   Java        Web
# 1840                                    3                   Java    Desktop
# 2716                                    2                 Kotlin     Mobile
# 620                                     1                 Kotlin    Desktop
# 552                                     8                 Python     Mobile
# 4050                                   15                   Java    Desktop
# 6634                                    8                 Python    Desktop
# 7198                                    6             Javascript        Web
# 305                                     7                   Java     Mobile
# 2441                                    5                   Java     Mobile
# 9271                                    9                   Java        Web
# 2990                                    4             Javascript    Desktop
# 6546                                    1                   Java        Web
# 9322                                   11                 Python    Desktop
# 5458                                    5                 Kotlin    Desktop
# 4852                                    2             Javascript        Web
# 7757                                   14                 Python        Web
# 9310                                    7                 Python     Mobile
# 8314                                   15                   Java     Mobile
# 7883                                    7                 Kotlin     Mobile
# 1098                                   10                 Python    Desktop
# 3546                                    4                 Python     Mobile
# 5200                                   14             Javascript        Web
# 8440                                    3                 Kotlin        Web
# 8903                                    5                 Python    Desktop
# 1384                                    3             Javascript    Desktop
# 9767                                    3                   Java        Web
# 7152                                    5                 Python     Mobile
# 4190                                    8                 Kotlin        Web
# 3323                                   14                 Python        Web
# 2772                                    7             Javascript        Web
# 5060                                    5                 Kotlin     Mobile
# 6135                                   13             Javascript        Web
# 9620                                    7             Javascript     Mobile
# 5340                                   10                 Kotlin     Mobile
# 6913                                   11                   Java     Mobile
# 236                                     7                 Kotlin     Mobile
# 2814                                    5                 Kotlin    Desktop
# 7100                                    3                 Kotlin        Web
# 4573                                    9                 Kotlin     Mobile
# 9242                                    7                 Python    Desktop
# 8427                                   11                   Java     Mobile
#
#        Tipo de proyecto Fase del proyecto  Tamaño del equipo  \
# 8064  Management System        Deployment                  8
# 7385  Management System        Deployment                  1
# 3404  Management System           Testing                  1
# 2711  Management System           Testing                  8
# 2591  Management System       Development                  6
# 3751  Management System        Deployment                 10
# 3793  Management System           Testing                  8
# 9090  Management System       Development                  1
# 4379  Management System        Deployment                  6
# 1840           Web site           Testing                  8
# 2716        Application            Design                  4
# 620   Management System        Deployment                  9
# 552   Management System       Development                 10
# 4050           Web site           Testing                  9
# 6634  Management System           Testing                  9
# 7198  Management System            Design                  5
# 305         Application        Deployment                  5
# 2441           Web site       Development                  9
# 9271        Application       Development                  2
# 2990  Management System        Deployment                  5
# 6546        Application       Development                  4
# 9322  Management System            Design                  5
# 5458        Application            Design                  1
# 4852           Web site            Design                  4
# 7757        Application            Design                  3
# 9310  Management System        Deployment                  5
# 8314  Management System            Design                  6
# 7883           Web site        Deployment                  6
# 1098           Web site       Development                  2
# 3546  Management System       Development                  6
# 5200  Management System            Design                  3
# 8440        Application           Testing                 10
# 8903  Management System        Deployment                  5
# 1384        Application        Deployment                  3
# 9767  Management System           Testing                  3
# 7152        Application        Deployment                  6
# 4190  Management System        Deployment                  9
# 3323           Web site           Testing                  4
# 2772        Application            Design                  4
# 5060           Web site            Design                 10
# 6135        Application           Testing                  6
# 9620        Application            Design                  7
# 5340  Management System       Development                  6
# 6913        Application            Design                  3
# 236   Management System            Design                  4
# 2814        Application           Testing                  2
# 7100        Application            Design                  8
# 4573           Web site       Development                  7
# 9242  Management System        Deployment                 10
# 8427        Application           Testing                  9
#
#                            Tecnologías
# 8064         energy, somebody, feeling
# 7385            its, sometimes, office
# 3404            exactly, girl, measure
# 2711         information, choose, walk
# 2591               state, let, control
# 3751  institution, certainly, somebody
# 3793         worry, collection, detail
# 9090                  meet, here, drug
# 4379              nation, tough, those
# 1840                baby, force, value
# 2716              example, upon, apply
# 620           politics, southern, many
# 552                     by, well, onto
# 4050             do, society, activity
# 6634        total, Congress, everybody
# 7198                wife, memory, term
# 305               write, service, hard
# 2441     everybody, yourself, Congress
# 9271             control, cold, always
# 2990            between, story, around
# 6546               will, foreign, part
# 9322               set, believe, could
# 5458                car, couple, fight
# 4852                   once, do, least
# 7757              rather, name, social
# 9310              decade, team, listen
# 8314          foreign, cover, actually
# 7883                   ever, road, top
# 1098          require, defense, couple
# 3546              subject, heart, fish
# 5200               ever, family, media
# 8440         consider, cultural, thing
# 8903             require, raise, coach
# 1384            especially, site, door
# 9767         resource, activity, focus
# 7152                    popular, I, in
# 4190         number, pretty, scientist
# 3323              give, official, cost
# 2772               partner, main, down
# 5060                office, our, reach
# 6135            social, service, drive
# 9620       brother, bar, international
# 5340              argue, spring, which
# 6913                watch, total, near
# 236                      last, care, I
# 2814           suggest, after, support
# 7100       hear, technology, establish
# 4573              early, police, stand
# 9242       recognize, language, either
# 8427          sign, generation, ground

# %% [markdown]
# #**Demostrar el tamaño de la muestra**

# %%
simple_size = len(simple_sample)
print("The simple size is over",simple_size)
# Out:
# The simple size is over 50

# %% [markdown]
# #**Descripcion de la muestra**

# %%
sample_description = simple_sample[['Costo (USD)', 'Tiempo de desarrollo (horas)']]
print("Descripcion de la muestra")
display(sample_description)
# Out:
# Descripcion de la muestra
#       Costo (USD)  Tiempo de desarrollo (horas)
# 8064        19630                           205
# 7385        65141                           500
# 3404        84563                            91
# 2711        81093                           142
# 2591        95408                           490
# 3751        29911                           479
# 3793        90855                           374
# 9090        35866                           189
# 4379        17540                           424
# 1840         6703                           149
# 2716        70983                           413
# 620         96545                           177
# 552         33976                           427
# 4050        52978                           326
# 6634        21165                            55
# 7198        17472                            75
# 305         79729                           470
# 2441         3371                           187
# 9271        59829                           214
# 2990        96070                           418
# 6546        91824                           335
# 9322        40008                           289
# 5458        28229                           284
# 4852         1654                           308
# 7757        79094                           350
# 9310        30084                           388
# 8314        80900                           375
# 7883        61846                           149
# 1098        62007                           449
# 3546        49164                           187
# 5200        19951                           213
# 8440        81347                           176
# 8903        37269                           407
# 1384        65466                           436
# 9767        28624                           224
# 7152        54868                           202
# 4190        49665                            51
# 3323        70629                           347
# 2772        93188                           171
# 5060        78778                           123
# 6135        55340                           428
# 9620        25787                           237
# 5340        28805                           263
# 6913        64638                           364
# 236         59975                            50
# 2814         9836                           217
# 7100        12520                           399
# 4573        27565                           402
# 9242        95616                           160
# 8427        12961                           446

# %% [markdown]
# #**Muestreo aleatorio sistematico**

# %% [markdown]
# #**Aplicacion sistematica de una muestra**
#
# ---

# %% [markdown]
# #**Definir el intervalo K (tamaño poblacion/muestra deseada)

# %%
simple_size = 80
interval = population_size // simple_size

print(population_size)
# Out:
# 10000

# %% [markdown]
# #**Seleccion de muestra sistematica**

# %%
systematic_sample = data.iloc[::interval]

# %% [markdown]
# #**Verificacion de la muestra**

# %%
print("Muestra obtenida a travez del muestreo sistematico")
display(systematic_sample)
# Out:
# Muestra obtenida a travez del muestreo sistematico
#                            Proyecto      Módulo    Desarrollador  \
# 0         Smith, Torres and Flowers        long    Patricia Ford
# 125        Parker, Parrish and Tate      office      Craig Wolfe
# 250        Thomas, Yang and Jenkins      series       Tina Rivas
# 375                       Olson LLC        both       Susan Todd
# 500   Dominguez, Vasquez and Miller      really  Taylor Robinson
# ...                             ...         ...              ...
# 9375                     Flores PLC        site        Jay Brown
# 9500  Adams, Simmons and Richardson  understand  Richard Johnson
# 9625                     Farley Ltd      series    Frank Merritt
# 9750              Vazquez-Hendricks     forward   Kristen Conrad
# 9875                Taylor and Sons    majority       Matthew Yu
#
#       Líneas de código  Número de bugs  Tiempo de desarrollo (horas)  \
# 0                 4227              39                           375
# 125               9569              12                           375
# 250               6157              47                           309
# 375                286              33                           231
# 500                693              36                           304
# ...                ...             ...                           ...
# 9375              5816               6                           487
# 9500              6457              38                           334
# 9625              6152               3                           292
# 9750              7886              16                           179
# 9875              4639              20                           335
#
#       Costo (USD)  Satisfacción del cliente  \
# 0           84053                         1
# 125         92730                         4
# 250         49045                         5
# 375         46265                         1
# 500         12845                         1
# ...           ...                       ...
# 9375        26443                         2
# 9500        76598                         4
# 9625        11181                         1
# 9750        22999                         2
# 9875        93315                         5
#
#       Antigüedad del desarrollador (años) Idioma de programación Plataforma  \
# 0                                      10                   Java     Mobile
# 125                                     3             Javascript        Web
# 250                                    10                 Kotlin     Mobile
# 375                                     2                   Java        Web
# 500                                    12                 Python        Web
# ...                                   ...                    ...        ...
# 9375                                    2                 Kotlin        Web
# 9500                                    3                 Python    Desktop
# 9625                                    1                 Python        Web
# 9750                                   10                 Kotlin        Web
# 9875                                    4                   Java     Mobile
#
#        Tipo de proyecto Fase del proyecto  Tamaño del equipo  \
# 0           Application        Deployment                  7
# 125   Management System       Development                  4
# 250         Application        Deployment                  9
# 375         Application        Deployment                 10
# 500         Application       Development                  2
# ...                 ...               ...                ...
# 9375        Application            Design                  6
# 9500  Management System       Development                  2
# 9625  Management System           Testing                  9
# 9750           Web site            Design                  7
# 9875           Web site       Development                  8
#
#                       Tecnologías
# 0       professor, evidence, down
# 125              idea, arm, place
# 250          any, strong, clearly
# 375          center, mouth, share
# 500          assume, after, there
# ...                           ...
# 9375            go, early, course
# 9500     soon, operation, outside
# 9625    anything, ahead, painting
# 9750        either, fast, general
# 9875  represent, explain, himself
#
# [80 rows x 15 columns]

# %% [markdown]
# #**Analizis de  poblacion**

# %% [markdown]
# #**Dividir la poblacion por tipo de proyecto**

# %%
grouped_by_project_type = data.groupby("Tipo de proyecto")
grouped_by_project_type.head()
# Out:
#                          Proyecto    Módulo          Desarrollador  \
# 0       Smith, Torres and Flowers      long          Patricia Ford
# 1                 Jordan and Sons      lose         Melissa Briggs
# 2      Madden, Jackson and Keller  thousand       Alexander Spence
# 3                     Evans Group     table         Michael Porter
# 4                     Pearson LLC     light         Andrew Gregory
# 5      Williams, Mckee and Kelley  audience           Jane Donovan
# 6   Harrison, Carroll and Barnett  attorney     Michael Fitzgerald
# 7                      Bean-Payne    decide       Jessica Williams
# 8            Fitzpatrick and Sons     small           Steven Allen
# 9                      Ray-Arnold      term          Deborah Davis
# 10                     Palmer PLC       age        Zachary Johnson
# 12                Valentine-Myers    ground  Mr. Alvin Gardner DVM
# 13     Armstrong, Hudson and Dunn   medical         Brandon Martin
# 15                Barnes and Sons  remember          Joshua Mosley
# 16                     Watson Inc      kind          Scott Mcmahon
#
#     Líneas de código  Número de bugs  Tiempo de desarrollo (horas)  \
# 0               4227              39                           375
# 1               6124              37                           132
# 2                588              30                           441
# 3               5796              17                            87
# 4               3019              11                           263
# 5               6300              41                           353
# 6               3932              36                           420
# 7                514              28                           102
# 8               4928               9                           341
# 9               3378              14                           208
# 10              5477              38                           142
# 12              2040              47                           396
# 13              6390              13                           178
# 15              3330               8                            82
# 16              1487              36                           110
#
#     Costo (USD)  Satisfacción del cliente  \
# 0         84053                         1
# 1         82167                         5
# 2         75204                         3
# 3         32147                         1
# 4         44998                         2
# 5         61827                         3
# 6          6515                         2
# 7         20075                         1
# 8          4663                         2
# 9         50665                         5
# 10        72981                         1
# 12        28246                         1
# 13         9107                         1
# 15        33327                         5
# 16        49796                         5
#
#     Antigüedad del desarrollador (años) Idioma de programación Plataforma  \
# 0                                    10                   Java     Mobile
# 1                                     9                 Kotlin     Mobile
# 2                                     7             Javascript     Mobile
# 3                                     1                 Kotlin     Mobile
# 4                                     5                 Python    Desktop
# 5                                    15                 Kotlin     Mobile
# 6                                     9                 Kotlin     Mobile
# 7                                     2                 Kotlin     Mobile
# 8                                     5                 Kotlin     Mobile
# 9                                     2                   Java    Desktop
# 10                                    5             Javascript     Mobile
# 12                                   14                 Python     Mobile
# 13                                    2             Javascript    Desktop
# 15                                   10                   Java     Mobile
# 16                                   14             Javascript        Web
#
#      Tipo de proyecto Fase del proyecto  Tamaño del equipo  \
# 0         Application        Deployment                  7
# 1   Management System           Testing                 10
# 2         Application        Deployment                 10
# 3         Application            Design                  1
# 4            Web site       Development                  3
# 5   Management System       Development                  4
# 6         Application           Testing                  6
# 7         Application        Deployment                  4
# 8            Web site        Deployment                  2
# 9            Web site       Development                  1
# 10           Web site       Development                  8
# 12           Web site            Design                  6
# 13  Management System       Development                 10
# 15  Management System           Testing                  1
# 16  Management System            Design                  2
#
#                    Tecnologías
# 0    professor, evidence, down
# 1            clear, rich, tend
# 2         process, cut, debate
# 3      bank, management, those
# 4           you, visit, camera
# 5         among, together, eye
# 6        popular, almost, hour
# 7   Democrat, establish, house
# 8         down, consumer, song
# 9             fall, major, arm
# 10  single, learn, development
# 12         provide, drop, fall
# 13        someone, today, hand
# 15          threat, hold, time
# 16         deep, later, camera

# %% [markdown]
# #**Calcular el promedio de lineas de codigo y bugs para cada subpoblacion**
#
# ---

# %%
group_analysis = grouped_by_project_type[["Líneas de código", "Número de bugs","Costo (USD)"]].mean()
display(group_analysis)
# Out:
#                    Líneas de código  Número de bugs   Costo (USD)
# Tipo de proyecto
# Application             5010.898008       25.308058  51179.995540
# Management System       5120.102603       25.029096  50514.636753
# Web site                5045.105872       24.800712  50707.962040

# %% [markdown]
# #**Mis 3 muestreos**

# %%
group_analysis = grouped_by_project_type[["Número de bugs", "Tiempo de desarrollo (horas)"]].mean()
display(group_analysis)
# Out:
#                    Número de bugs  Tiempo de desarrollo (horas)
# Tipo de proyecto
# Application             25.308058                    255.396670
# Management System       25.029096                    253.509648
# Web site                24.800712                    255.163998

# %% [markdown]
# <br>

# %%
group_analysis = grouped_by_project_type[["Costo (USD)", "Antigüedad del desarrollador (años)"]].mean()
display(group_analysis)
# Out:
#                     Costo (USD)  Antigüedad del desarrollador (años)
# Tipo de proyecto
# Application        51179.995540                             7.856081
# Management System  50514.636753                             8.014701
# Web site           50707.962040                             7.876038

# %% [markdown]
# <br>

# %%
group_analysis = grouped_by_project_type[["Satisfacción del cliente", "Tamaño del equipo"]].mean()
display(group_analysis)
# Out:
#                    Satisfacción del cliente  Tamaño del equipo
# Tipo de proyecto
# Application                        3.011894           5.584597
# Management System                  2.966003           5.479632
# Web site                           3.025801           5.417260
